# %% [markdown]
# # Compile, visualize and analyze results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.__version__
# Out:
# '0.23.0'

# %%
list_heads = ['desc']
list_folds = range(2, 50)
for l in list_folds:
    list_heads.append('fold_'+ str(l))
    list_heads.append('mean_'+ str(l))    
    list_heads.append('std_'+ str(l))

list_heads.append('blank')    
print(list_heads)
print(type(list_heads))
print(len(list_heads))
print(list_folds)
# Out:
# ['desc', 'fold_2', 'mean_2', 'std_2', 'fold_3', 'mean_3', 'std_3', 'fold_4', 'mean_4', 'std_4', 'fold_5', 'mean_5', 'std_5', 'fold_6', 'mean_6', 'std_6', 'fold_7', 'mean_7', 'std_7', 'fold_8', 'mean_8', 'std_8', 'fold_9', 'mean_9', 'std_9', 'fold_10', 'mean_10', 'std_10', 'fold_11', 'mean_11', 'std_11', 'fold_12', 'mean_12', 'std_12', 'fold_13', 'mean_13', 'std_13', 'fold_14', 'mean_14', 'std_14', 'fold_15', 'mean_15', 'std_15', 'fold_16', 'mean_16', 'std_16', 'fold_17', 'mean_17', 'std_17', 'fold_18', 'mean_18', 'std_18', 'fold_19', 'mean_19', 'std_19', 'fold_20', 'mean_20', 'std_20', 'fold_21', 'mean_21', 'std_21', 'fold_22', 'mean_22', 'std_22', 'fold_23', 'mean_23', 'std_23', 'fold_24', 'mean_24', 'std_24', 'fold_25', 'mean_25', 'std_25', 'fold_26', 'mean_26', 'std_26', 'fold_27', 'mean_27', 'std_27', 'fold_28', 'mean_28', 'std_28', 'fold_29', 'mean_29', 'std_29', 'fold_30', 'mean_30', 'std_30', 'fold_31', 'mean_31', 'std_31', 'fold_32', 'mean_32', 'std_32', 'fold_33', 'mean_33',
# ...

# %%
Gaus_pd = pd.read_csv('GaussianNB1.txt', sep=" ", header=None) #, names=list_heads)
RaF_pd = pd.read_csv('RandomForest1.txt', sep=" ", header=None) #, names=list_heads)
SVC_pd = pd.read_csv('SVC1.txt', sep=" ", header=None) #, names=list_heads)

Gaus_pd.columns = list_heads
RaF_pd.columns = list_heads
SVC_pd.columns = list_heads

del Gaus_pd['blank']
del RaF_pd['blank']
del SVC_pd['blank']
#Frame_GaussianNB = pd.DataFrame([GaussianNB_ser], columns = list_heads)
#DecisionTree_ser = pd.read_csv('DecisionTree.txt', sep=" ")

# %% [markdown]
# ## Gaussian Naive results

# %%
Gaus_pd.describe()
# Out:
#        fold_2     mean_2      std_2  fold_3     mean_3      std_3  fold_4  \
# count    48.0  48.000000  48.000000    48.0  48.000000  48.000000    48.0
# mean      2.0   0.747917   0.066250     3.0   0.771458   0.092292     4.0
# std       0.0   0.115057   0.059667     0.0   0.115353   0.053604     0.0
# min       2.0   0.580000   0.000000     3.0   0.580000   0.010000     4.0
# 25%       2.0   0.620000   0.020000     3.0   0.695000   0.050000     4.0
# 50%       2.0   0.790000   0.060000     3.0   0.820000   0.090000     4.0
# 75%       2.0   0.860000   0.085000     3.0   0.880000   0.125000     4.0
# max       2.0   0.880000   0.220000     3.0   0.900000   0.250000     4.0
#
#           mean_4      std_4  fold_5    ...        std_46  fold_47    mean_47  \
# count  48.000000  48.000000    48.0    ...     48.000000     48.0  48.000000
# mean    0.779167   0.102292     5.0    ...      0.372708     47.0   0.789583
# ...

# %%
Gaus_pd.head(2)
# Out:
#        desc  fold_2  mean_2  std_2  fold_3  mean_3  std_3  fold_4  mean_4  \
# 0  o4-c8-b1       2    0.70   0.22       3    0.80   0.17       4    0.77
# 1  o4-c8-b2       2    0.84   0.04       3    0.82   0.09       4    0.86
#
#    std_4   ...    std_46  fold_47  mean_47  std_47  fold_48  mean_48  std_48  \
# 0   0.27   ...      0.36       47     0.85    0.34       48     0.85    0.34
# 1   0.10   ...      0.29       47     0.89    0.31       48     0.90    0.31
#
#    fold_49  mean_49  std_49
# 0       49     0.84    0.37
# 1       49     0.90    0.30
#
# [2 rows x 145 columns]

# %% [markdown]
# ## Random Forest results

# %%
RaF_pd.describe()
# Out:
#           mean_2      std_2  fold_3     mean_3      std_3  fold_4     mean_4  \
# count  48.000000  48.000000    48.0  48.000000  48.000000    48.0  48.000000
# mean    0.787083   0.041250     3.0   0.804167   0.067708     4.0   0.811042
# std     0.078224   0.035348     0.0   0.065747   0.035624     0.0   0.056011
# min     0.580000   0.000000     3.0   0.660000   0.010000     4.0   0.660000
# 25%     0.755000   0.020000     3.0   0.760000   0.050000     4.0   0.775000
# 50%     0.800000   0.040000     3.0   0.820000   0.060000     4.0   0.820000
# 75%     0.840000   0.060000     3.0   0.845000   0.090000     4.0   0.845000
# max     0.920000   0.180000     3.0   0.920000   0.150000     4.0   0.900000
#
#            std_4  fold_5     mean_5    ...         std_46  fold_47    mean_47  \
# count  48.000000    48.0  48.000000    ...      48.000000     48.0  48.000000
# mean    0.085833     5.0   0.821667    ...       0.358958     47.0   0.830833
# ...

# %%
RaF_pd.head(2)
# Out:
#   desc    fold_2  mean_2  std_2  fold_3  mean_3  std_3  fold_4  mean_4  std_4  \
# 0    o  4-c8-b12    0.76   0.08       3    0.74   0.11       4    0.72   0.15
# 1    o  4-c8-b22    0.78   0.06       3    0.80   0.07       4    0.80   0.10
#
#     ...    std_46  fold_47  mean_47  std_47  fold_48  mean_48  std_48  \
# 0   ...      0.38       47     0.77    0.42       48     0.85    0.34
# 1   ...      0.32       47     0.74    0.42       48     0.78    0.41
#
#    fold_49  mean_49  std_49
# 0       49     0.79    0.40
# 1       49     0.73    0.44
#
# [2 rows x 145 columns]

# %% [markdown]
# ## Support vector Machine

# %%
SVC_pd.describe()
# Out:
#           mean_2      std_2  fold_3     mean_3      std_3  fold_4     mean_4  \
# count  48.000000  48.000000    48.0  48.000000  48.000000    48.0  48.000000
# mean    0.517917   0.048750     3.0   0.549375   0.091667     4.0   0.574583
# std     0.093739   0.026708     0.0   0.074303   0.044018     0.0   0.038202
# min     0.360000   0.020000     3.0   0.360000   0.010000     4.0   0.400000
# 25%     0.400000   0.020000     3.0   0.580000   0.050000     4.0   0.580000
# 50%     0.580000   0.060000     3.0   0.580000   0.095000     4.0   0.580000
# 75%     0.580000   0.080000     3.0   0.580000   0.120000     4.0   0.580000
# max     0.580000   0.080000     3.0   0.650000   0.210000     4.0   0.630000
#
#            std_4  fold_5     mean_5      ...          std_46  fold_47  \
# count  48.000000    48.0  48.000000      ...       48.000000     48.0
# mean    0.115208     5.0   0.576667      ...        0.481667     47.0
# ...

# %%
SVC_pd.head(2)
# Out:
#   desc    fold_2  mean_2  std_2  fold_3  mean_3  std_3  fold_4  mean_4  std_4  \
# 0    o  4-c8-b12    0.58   0.06       3    0.40   0.13       4    0.58   0.14
# 1    o  4-c8-b22    0.58   0.02       3    0.38   0.14       4    0.58   0.17
#
#     ...    std_46  fold_47  mean_47  std_47  fold_48  mean_48  std_48  \
# 0   ...      0.48       47     0.57    0.48       48     0.56    0.50
# 1   ...      0.48       47     0.60    0.48       48     0.59    0.49
#
#    fold_49  mean_49  std_49
# 0       49     0.58    0.49
# 1       49     0.58    0.49
#
# [2 rows x 145 columns]

# %%
nfolds_range = range(2,50)
plt.plot(nfolds_range, Gaus_pd.mean_10, label="mean", color="red")
plt.plot(nfolds_range, Gaus_pd.mean_11, label="mean", color="red")
plt.plot(nfolds_range, Gaus_pd.mean_12, label="mean", color="blue")
plt.plot(nfolds_range, Gaus_pd.mean_13, label="mean", color="black")
plt.plot(nfolds_range, Gaus_pd.mean_14, label="mean", color="black")
plt.plot(nfolds_range, Gaus_pd.mean_15, label="mean", color="black")
plt.plot(nfolds_range, Gaus_pd.mean_16, label="mean", color="black")
plt.plot(nfolds_range, Gaus_pd.mean_17, label="mean", color="black")
#plt.fill_between(nfolds_range, Gaus_pd.mean_10-Gaus_pd., means+stds, color="blue", alpha=.5, label="std")

# %%
nfolds_range = range(2,50)
plt.plot(nfolds_range, SVC_pd.mean_10, label="mean", color="red")
plt.plot(nfolds_range, SVC_pd.mean_11, label="mean", color="red")
plt.plot(nfolds_range, SVC_pd.mean_12, label="mean", color="blue")
plt.plot(nfolds_range, SVC_pd.mean_13, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_14, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_15, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_16, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_17, label="mean", color="black")

# %%
nfolds_range = range(2,50)
plt.plot(nfolds_range, RaF_pd.mean_10, label="mean", color="red")
plt.plot(nfolds_range, RaF_pd.mean_11, label="mean", color="red")
plt.plot(nfolds_range, RaF_pd.mean_12, label="mean", color="blue")
plt.plot(nfolds_range, RaF_pd.mean_13, label="mean", color="black")
plt.plot(nfolds_range, S.mean_14, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_15, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_16, label="mean", color="black")
plt.plot(nfolds_range, SVC_pd.mean_17, label="mean", color="black")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-32dc61a31ad6> in <module>()
#       4 plt.plot(nfolds_range, RaF_pd.mean_12, label="mean", color="blue")
#       5 plt.plot(nfolds_range, RaF_pd.mean_13, label="mean", color="black")
# ----> 6 plt.plot(nfolds_range, S.mean_14, label="mean", color="black")
#       7 plt.plot(nfolds_range, SVC_pd.mean_15, label="mean", color="black")
#       8 plt.plot(nfolds_range, SVC_pd.mean_16, label="mean", color="black")
#
# NameError: name 'S' is not defined
